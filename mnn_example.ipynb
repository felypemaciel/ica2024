# %%
import numpy as np, pandas as pd
from matplotlib.pyplot import subplots
from sklearn.linear_model import (LinearRegression, LogisticRegression, Lasso)
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import KFold
from sklearn.pipeline import Pipeline
from ISLP import load_data
from ISLP.models import ModelSpec as MS
from sklearn.model_selection import (train_test_split, GridSearchCV)

# %%
import torch
from torch import nn
from torch.optim import RMSprop
from torch.utils.data import TensorDataset

# %%
from torchmetrics import (MeanAbsoluteError, R2Score)
from torchinfo import summary
from torchvision.io import read_image

# %%
from torchvision.datasets import MNIST, CIFAR100
from torchvision.models import (resnet50, ResNet50_Weights)
from torchvision.transforms import (Resize,
                                    Normalize,
                                    CenterCrop,
                                    ToTensor)

# %%
(mnist_train, mnist_test) = [MNIST(root='data',
                                      train=train,
                                      download=True,
                                      transofrm=ToTensor())
                                      for train in [True, False]]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 (mnist_train, mnist_test) = [MNIST(root='data',
#       2                                       train=train,
#       3                                       download=True,
#       4                                       transofrm=ToTensor())
#       5                                       for train in [True, False]]
#
# TypeError: MNIST.__init__() got an unexpected keyword argument 'transofrm'

# %%
import numpy as np

# Example matrix
matrix = np.array([
    [10, 40, 30, 20],
    [5, 15, 25, 35],
    [8, 18, 28, 38]
])

# Get the indices of the three largest values in each row, sorted in descending order
top_3_indices = np.argsort(matrix, axis=1)[:, -3:][:, ::-1]

print(top_3_indices)
# Out:
# [[1 2 3]
#  [3 2 1]
#  [3 2 1]]

# %% [markdown]
# ### Neural Networks - One Hot Encoding

# %%
import keras
from keras import layers

# %%
fontlabel=14
fontticks=12

# %%
import numpy as np
import matplotlib.pyplot as plt

def logistic(x, L=1, k=1, x0=0):
    """
    Compute the logistic function.

    Parameters:
    x : float or array-like
        Input value(s).
    L : float, optional (default=1)
        The curve's maximum value.
    k : float, optional (default=1)
        The logistic growth rate (steepness of the curve).
    x0 : float, optional (default=0)
        The x-value of the sigmoid's midpoint.

    Returns:
    float or numpy array
        The logistic function value at x.
    """
    return L / (1 + np.exp(-k * (x - x0)))

# Generate x values
x = np.linspace(-10, 10, 100)

# Compute logistic function values
y = logistic(x, L=1, k=1.5, x0=3)

# Plot the function
fig = plt.figure(dpi=300)

plt.plot(x, y, label='Logistic Function')
# plt.axvline(0, color='gray', linestyle='--', alpha=0.5)
plt.axhline(0.5, color='gray', linestyle='--', alpha=0.5)
plt.xlabel("$X$", fontsize=fontlabel)
plt.ylabel("$p(X)$", fontsize=fontlabel)

xticks = [-10, -5, 0, 5, 10]
yticks = [0, 0.25, 0.5, 0.75, 1]

plt.xticks(xticks, fontsize=fontticks)
plt.yticks(yticks, fontsize=fontticks)

plt.show()

fig.savefig('../ica2024-report/homework3/figures/logistic-function.pdf', format='pdf', bbox_inches='tight')
